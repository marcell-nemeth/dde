# %% [markdown]
# ## Notebook for Running Experiments on CovType Data Set

# %%
from typing import List
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# C:\Users\MarcellNemeth\AppData\Roaming\Python\Python39\site-packages\matplotlib\projections\__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd()))

import scipy
import pickle
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from labellines import labelLines
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# import nannyml as nml
from test_harness.datasets.dataset import Dataset

# %%
from  test_harness.experiments.dde_experiment import DDEffectExperiment

# %% [markdown]
# ## Load Data

# %%
with open("../data/covtype_induced_drift_forward_norm.pkl", "rb") as f:
    drift_df, change_points = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\MARCEL~1\AppData\Local\Temp/ipykernel_11904/1306110058.py in <module>
# ----> 1 with open("../data/covtype_induced_drift_forward_norm.pkl", "rb") as f:
#       2     drift_df, change_points = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/covtype_induced_drift_forward_norm.pkl'

# %%
change_points
# Out:
# [0, 123785, 247570, 371355]

# %% [markdown]
# ## Experiments
#
# ### Prepare Test Harness

# %%
# specify columns and if categorical
col_names = [
    ("elevation", False),
    ("aspect", False),
    ("slope", False),
    ("horizontal_dist_to_hydrology", False),
    ("vertical_dist_to_hydrology", False),
    ("horizontal_dist_to_roadways", False),
    ("hillshade_9am", False),
    ("hillshade_noon", False),
    ("hillshade_3pm", False),
    ("horizontal_dist_to_fire_points", False),
]
wilderness_area_cols = [(f"wilderness_area_{i+1}", True) for i in range(4)]
col_names = col_names + wilderness_area_cols + [("cover_type", True)]

# %%
column_mapping = {
    "target": "cover_type",
    "numerical_features": [col for col, iscat in col_names if not iscat],
    "categorical_features": [col for col, iscat in col_names if iscat][:-1],
}

CT_dataset = Dataset(
    full_df=drift_df, column_mapping=column_mapping, window_size=17500 * 2, change_points=change_points, reference_size=1000,
)
# Out:
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\datasets\dataset.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.reference_df['period'] = 'reference'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\datasets\dataset.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.reference_df['sample_num'] = self.reference_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\datasets\dataset.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.analysis_df['period'] = 'analysis'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\datasets\dataset.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.analysis_df['sample_num'] = self.analysis_df.index

# %%
CT_dataset.analysis_df
# Out:
#         elevation    aspect     slope  horizontal_dist_to_hydrology  \
# 1000     0.552461  0.119444  0.348485                      0.349320
# 1001     0.441062  0.536111  0.272727                      0.365068
# 1002     0.698834  0.250000  0.181818                      0.193271
# 1003     0.550518  0.300000  0.469697                      0.344309
# 1004     0.627591  0.916667  0.121212                      0.107373
# ...           ...       ...       ...                           ...
# 495136   0.065523  0.948819  0.736220                      0.376985
# 495137   0.121428  0.988189  0.791339                      0.439652
# 495138   0.062178  0.874016  0.594488                      0.706758
# 495139   0.370277  0.866142  0.433071                      0.509344
# 495140   0.121288  0.716535  0.334646                      0.655894
#
#         vertical_dist_to_hydrology  horizontal_dist_to_roadways  \
# 1000                      0.329457                     0.644232
# 1001                      0.335917                     0.191794
# 1002                      0.271318                     0.024589
# 1003                      0.436693                     0.152311
# 1004                      0.237726                     0.137277
# ...                            ...                          ...
# 495136                    0.763780                     0.531736
# 495137                    0.732283                     0.587435
# 495138                    0.818898                     0.646373
# 495139                    0.937008                     0.516192
# 495140                    0.862205                     0.613990
#
#         hillshade_9am  hillshade_noon  hillshade_3pm  \
# 1000         0.854331        0.724409       0.358268
# 1001         0.846457        0.988189       0.645669
# 1002         0.940945        0.866142       0.000000
# 1003         1.000000        0.740157       0.149606
# 1004         0.795276        0.909449       0.661417
# ...               ...             ...            ...
# 495136       0.266150        0.777778       0.136364
# 495137       0.248062        0.677778       0.242424
# 495138       0.298450        0.011111       0.136364
# 495139       0.227390        0.244444       0.181818
# 495140       0.281654        0.127778       0.363636
#
#         horizontal_dist_to_fire_points  wilderness_area_1  wilderness_area_2  \
# 1000                          0.550118                1.0                0.0
# 1001                          0.101771                0.0                0.0
# 1002                          0.231981                0.0                1.0
# 1003                          0.084065                1.0                0.0
# 1004                          0.243831                0.0                1.0
# ...                                ...                ...                ...
# 495136                        0.107373                0.0                1.0
# 495137                        0.085898                0.0                1.0
# 495138                        0.202577                0.0                0.0
# 495139                        0.021475                0.0                0.0
# 495140                        0.173228                0.0                0.0
#
#         wilderness_area_3  wilderness_area_4  cover_type    period  sample_num
# 1000                  0.0                0.0         0.0  analysis        1000
# 1001                  1.0                0.0         1.0  analysis        1001
# 1002                  0.0                0.0         0.0  analysis        1002
# 1003                  0.0                0.0         1.0  analysis        1003
# 1004                  0.0                0.0         0.0  analysis        1004
# ...                   ...                ...         ...       ...         ...
# 495136                0.0                0.0         1.0  analysis      495136
# 495137                0.0                0.0         1.0  analysis      495137
# 495138                0.0                1.0         1.0  analysis      495138
# 495139                0.0                1.0         1.0  analysis      495139
# 495140                0.0                1.0         1.0  analysis      495140
#
# [494141 rows x 17 columns]

# %%
max_comp_num = drift_df.shape[1]

# %% [markdown]
# #### EDA on dataset

# %%
#CT_dataset.full_df.corr().to_csv('full_correlation.csv')

# %%
# plt.figure(figsize=(12,10))
# sns.heatmap(CT_dataset.full_df.corr(), annot=True)
#
# plt.title('Original dataset correlation map')
# #plt.show()

# %% [markdown]
# ## Run Experiments

# %%
def windowed_correlation(df, mode='expanding'):
    corr_dict = {}
    columns = df.columns
    n = len(columns)
    for i in range(n):
        for j in range(i+1, n):
            col1 = columns[i]
            col2 = columns[j]
            key = (col1, col2)

            if mode=='expanding':
                corr_dict[key] = df[col1].expanding(10).corr(df[col2])
            else:
                corr_dict[key] = df[col1].rolling(window=10).corr(df[col2])

            corr_dict[key] = corr_dict[key].fillna(0)

    return corr_dict

# %%
def plot_windowed_correlation(corr_dict, vertical_lines):
    plt.figure(figsize=(15,10))
    for (col1, col2), corr in corr_dict.items():
        plt.plot(corr, label=f"{col1} vs {col2}")

    if vertical_lines:
        [plt.axvline(x, color='gray', linestyle='--') for x in vertical_lines if x != 0]

    plt.legend(bbox_to_anchor=(1, 0.5))
    #labelLines(plt.gca().get_lines(), align=True)
    plt.show()

# %%
corr_dict = windowed_correlation(CT_dataset.full_df.loc[:, CT_dataset.full_df.columns[:5]], mode='expanding')

# %%
#plot_windowed_correlation(corr_dict, change_points)

# %%
column_names = list(CT_dataset.reference_df.columns[:3])

# %%
column_names
# Out:
# ['elevation', 'aspect', 'slope']

# %%
calc = nml.UnivariateDriftCalculator(
    column_names=column_names,
    #timestamp_column_name='sample_num',
    continuous_methods=['jensen_shannon'],
    categorical_methods=['jensen_shannon'],
    #chunk_number=10,
    chunk_size=1000,
)

calc.fit(CT_dataset.reference_df)
# Out:
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(

# %%
results = calc.calculate(CT_dataset.analysis_df)

# %%
change_points
# Out:
# [0, 123785, 247570, 371355]

# %%
results_js = results.filter(column_names=results.continuous_column_names, methods=['jensen_shannon']).to_df()
results_js.columns = ['_'.join(col) for col in results_js.columns.values]
display(results_js)
# Out:
#      chunk_chunk_key  chunk_chunk_chunk_index  chunk_chunk_start_index  \
# 0            [0:999]                        0                        0
# 1        [1000:1999]                        1                     1000
# 2        [2000:2999]                        2                     2000
# 3        [3000:3999]                        3                     3000
# 4        [4000:4999]                        4                     4000
# ..               ...                      ...                      ...
# 489  [489000:489999]                      489                   489000
# 490  [490000:490999]                      490                   490000
# 491  [491000:491999]                      491                   491000
# 492  [492000:492999]                      492                   492000
# 493  [493000:494140]                      493                   493000
#
#      chunk_chunk_end_index chunk_chunk_start_date chunk_chunk_end_date  \
# 0                      999                   None                 None
# 1                     1999                   None                 None
# 2                     2999                   None                 None
# 3                     3999                   None                 None
# 4                     4999                   None                 None
# ..                     ...                    ...                  ...
# 489                 489999                   None                 None
# 490                 490999                   None                 None
# 491                 491999                   None                 None
# 492                 492999                   None                 None
# 493                 494140                   None                 None
#
#     chunk_chunk_period  elevation_jensen_shannon_value  \
# 0             analysis                        0.063515
# 1             analysis                        0.077553
# 2             analysis                        0.083784
# 3             analysis                        0.095652
# 4             analysis                        0.076902
# ..                 ...                             ...
# 489           analysis                        0.665190
# 490           analysis                        0.673800
# 491           analysis                        0.681018
# 492           analysis                        0.659580
# 493           analysis                        0.675486
#
#      elevation_jensen_shannon_upper_threshold  \
# 0                                         0.1
# 1                                         0.1
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
# ..                                        ...
# 489                                       0.1
# 490                                       0.1
# 491                                       0.1
# 492                                       0.1
# 493                                       0.1
#
#     elevation_jensen_shannon_lower_threshold  elevation_jensen_shannon_alert  \
# 0                                       None                           False
# 1                                       None                           False
# 2                                       None                           False
# 3                                       None                           False
# 4                                       None                           False
# ..                                       ...                             ...
# 489                                     None                            True
# 490                                     None                            True
# 491                                     None                            True
# 492                                     None                            True
# 493                                     None                            True
#
#      aspect_jensen_shannon_value  aspect_jensen_shannon_upper_threshold  \
# 0                       0.062814                                    0.1
# 1                       0.061739                                    0.1
# 2                       0.073345                                    0.1
# 3                       0.075364                                    0.1
# 4                       0.100437                                    0.1
# ..                           ...                                    ...
# 489                     0.743952                                    0.1
# 490                     0.743605                                    0.1
# 491                     0.732158                                    0.1
# 492                     0.749612                                    0.1
# 493                     0.742592                                    0.1
#
#     aspect_jensen_shannon_lower_threshold  aspect_jensen_shannon_alert  \
# 0                                    None                        False
# 1                                    None                        False
# 2                                    None                        False
# 3                                    None                        False
# 4                                    None                         True
# ..                                    ...                          ...
# 489                                  None                         True
# 490                                  None                         True
# 491                                  None                         True
# 492                                  None                         True
# 493                                  None                         True
#
#      slope_jensen_shannon_value  slope_jensen_shannon_upper_threshold  \
# 0                      0.136551                                   0.1
# 1                      0.111720                                   0.1
# 2                      0.120565                                   0.1
# 3                      0.121987                                   0.1
# 4                      0.128900                                   0.1
# ..                          ...                                   ...
# 489                    0.997565                                   0.1
# 490                    0.997465                                   0.1
# 491                    0.997796                                   0.1
# 492                    0.997375                                   0.1
# 493                    0.997341                                   0.1
#
#     slope_jensen_shannon_lower_threshold  slope_jensen_shannon_alert
# 0                                   None                        True
# 1                                   None                        True
# 2                                   None                        True
# 3                                   None                        True
# 4                                   None                        True
# ..                                   ...                         ...
# 489                                 None                        True
# 490                                 None                        True
# 491                                 None                        True
# 492                                 None                        True
# 493                                 None                        True
#
# [494 rows x 19 columns]

# %%
results_js.columns
# Out:
# Index(['chunk_chunk_key', 'chunk_chunk_chunk_index', 'chunk_chunk_start_index',
#        'chunk_chunk_end_index', 'chunk_chunk_start_date',
#        'chunk_chunk_end_date', 'chunk_chunk_period',
#        'elevation_jensen_shannon_value',
#        'elevation_jensen_shannon_upper_threshold',
#        'elevation_jensen_shannon_lower_threshold',
#        'elevation_jensen_shannon_alert', 'aspect_jensen_shannon_value',
#        'aspect_jensen_shannon_upper_threshold',
#        'aspect_jensen_shannon_lower_threshold', 'aspect_jensen_shannon_alert',
#        'slope_jensen_shannon_value', 'slope_jensen_shannon_upper_threshold',
#        'slope_jensen_shannon_lower_threshold', 'slope_jensen_shannon_alert'],
#       dtype='object')

# %%
results_js[['aspect_jensen_shannon_value', 'elevation_jensen_shannon_value', 'slope_jensen_shannon_value']].plot()
# Out:
# <AxesSubplot:>

# %%
#figure = results.filter(column_names=results.continuous_column_names, methods=['jensen_shannon']).plot(kind='drift')
#figure.show()

# %%
# figure = results.filter(column_names=results.continuous_column_names, methods=['jensen_shannon']).plot(kind='distribution')
# figure.show()

# %% [markdown]
# ### Own Jensen-Shannon

# %%
dde_exp_eq_radius = DDEffectExperiment(_dataset=CT_dataset)
dde_exp_eq_radius.changepoint_radius_driftscore(radius_left=1000, radius_right=1000)
display(dde_exp_eq_radius.results_all)
# Out:
# 122785 123785 124785
# 246570 247570 248570
# 370355 371355 372355
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ref_df['period'] = 'reference'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ref_df['sample_num'] = ref_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['period'] = 'analysis'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['sample_num'] = analysis_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ref_df['period'] = 'reference'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ref_df['sample_num'] = ref_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['period'] = 'analysis'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['sample_num'] = analysis_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ref_df['period'] = 'reference'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ref_df['sample_num'] = ref_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['period'] = 'analysis'
# D:\Dokumentumok\BME\PhD\codes\dde\test_harness\experiments\dde_experiment.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['sample_num'] = analysis_df.index
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
# D:\Dokumentumok\BME\PhD\codes\dde\venv\lib\site-packages\nannyml\chunk.py:181: UserWarning: The resulting number of chunks is too low. Please consider splitting your data in a different way or continue at your own risk.
#   warnings.warn(
#     start  change_point     end  elevation    aspect     slope  \
# 0  122785        123785  124785   0.677523  0.044935  0.127194
# 1  246570        247570  248570   0.082540  0.738349  0.995522
# 2  370355        371355  372355   0.102926  0.090526  0.071732
#
#    horizontal_dist_to_hydrology  vertical_dist_to_hydrology  \
# 0                      0.354763                    0.052703
# 1                      0.090822                    0.975469
# 2                      0.080801                    0.070375
#
#    horizontal_dist_to_roadways  hillshade_9am  hillshade_noon  hillshade_3pm  \
# 0                     0.575389       0.058876        0.080126       0.091013
# 1                     0.104845       0.974967        0.714436       0.844548
# 2                     0.079738       0.076800        0.054189       0.122517
#
#    horizontal_dist_to_fire_points  wilderness_area_1  wilderness_area_2  \
# 0                        0.281122           0.015273           0.003494
# 1                        0.080445           0.003394           0.012981
# 2                        0.092047           0.541940           0.365868
#
#    wilderness_area_3  wilderness_area_4  cover_type  sample_num
# 0           0.017127           0.024410    0.002565     0.99801
# 1           0.001707           0.005743    0.013717     0.99801
# 2           0.365998           0.542663    0.006838     0.99801

# %%
dde_exp_eq_radius.changepoint_radius_corr(radius_left=1000, radius_right=1000)
# Out:
# 122785 123785 124785
# 246570 247570 248570
# 370355 371355 372355

# %% [markdown]
# #### Change point 1

# %%
dde_exp_eq_radius.corr_scores[123785]['reference']
# Out:
#                                 elevation    aspect     slope  \
# elevation                        1.000000  0.113262 -0.107275
# aspect                           0.113262  1.000000  0.040930
# slope                           -0.107275  0.040930  1.000000
# horizontal_dist_to_hydrology     0.254587  0.048018  0.038552
# vertical_dist_to_hydrology       0.107896  0.085706  0.287666
# horizontal_dist_to_roadways      0.225160  0.093875 -0.150567
# hillshade_9am                   -0.019738 -0.553944 -0.251319
# hillshade_noon                   0.178264  0.421426 -0.424437
# hillshade_3pm                    0.121398  0.634532 -0.172299
# horizontal_dist_to_fire_points  -0.005812 -0.075016 -0.093417
# wilderness_area_1               -0.074194 -0.119261 -0.211997
# wilderness_area_2                0.293780  0.079559 -0.014114
# wilderness_area_3               -0.051586  0.077403  0.216616
# wilderness_area_4               -0.167524  0.031304  0.033690
# cover_type                      -0.472416 -0.023925  0.085259
#
#                                 horizontal_dist_to_hydrology  \
# elevation                                           0.254587
# aspect                                              0.048018
# slope                                               0.038552
# horizontal_dist_to_hydrology                        1.000000
# vertical_dist_to_hydrology                          0.575408
# horizontal_dist_to_roadways                         0.059654
# hillshade_9am                                      -0.069723
# hillshade_noon                                      0.084322
# hillshade_3pm                                       0.092072
# horizontal_dist_to_fire_points                      0.053977
# wilderness_area_1                                  -0.142245
# wilderness_area_2                                   0.058207
# wilderness_area_3                                   0.120530
# wilderness_area_4                                  -0.054809
# cover_type                                          0.117451
#
#                                 vertical_dist_to_hydrology  \
# elevation                                         0.107896
# aspect                                            0.085706
# slope                                             0.287666
# horizontal_dist_to_hydrology                      0.575408
# vertical_dist_to_hydrology                        1.000000
# horizontal_dist_to_roadways                       0.036474
# hillshade_9am                                    -0.165036
# hillshade_noon                                   -0.005153
# hillshade_3pm                                     0.078069
# horizontal_dist_to_fire_points                   -0.003627
# wilderness_area_1                                -0.165061
# wilderness_area_2                                -0.019340
# wilderness_area_3                                 0.176895
# wilderness_area_4                                -0.011255
# cover_type                                        0.116418
#
#                                 horizontal_dist_to_roadways  hillshade_9am  \
# elevation                                          0.225160      -0.019738
# aspect                                             0.093875      -0.553944
# slope                                             -0.150567      -0.251319
# horizontal_dist_to_hydrology                       0.059654      -0.069723
# vertical_dist_to_hydrology                         0.036474      -0.165036
# horizontal_dist_to_roadways                        1.000000      -0.025418
# hillshade_9am                                     -0.025418       1.000000
# hillshade_noon                                     0.172900      -0.143877
# hillshade_3pm                                      0.126158      -0.823842
# horizontal_dist_to_fire_points                     0.273383       0.088692
# wilderness_area_1                                  0.446747       0.181174
# wilderness_area_2                                 -0.245640       0.005351
# wilderness_area_3                                 -0.321413      -0.179672
# wilderness_area_4                                 -0.065821      -0.048279
# cover_type                                        -0.050993       0.038866
#
#                                 hillshade_noon  hillshade_3pm  \
# elevation                             0.178264       0.121398
# aspect                                0.421426       0.634532
# slope                                -0.424437      -0.172299
# horizontal_dist_to_hydrology          0.084322       0.092072
# vertical_dist_to_hydrology           -0.005153       0.078069
# horizontal_dist_to_roadways           0.172900       0.126158
# hillshade_9am                        -0.143877      -0.823842
# hillshade_noon                        1.000000       0.657501
# hillshade_3pm                         0.657501       1.000000
# horizontal_dist_to_fire_points        0.025591      -0.042049
# wilderness_area_1                    -0.019655      -0.120490
# wilderness_area_2                     0.043954       0.020313
# wilderness_area_3                    -0.001595       0.107467
# wilderness_area_4                    -0.002464       0.034523
# cover_type                            0.020962      -0.037835
#
#                                 horizontal_dist_to_fire_points  \
# elevation                                            -0.005812
# aspect                                               -0.075016
# slope                                                -0.093417
# horizontal_dist_to_hydrology                          0.053977
# vertical_dist_to_hydrology                           -0.003627
# horizontal_dist_to_roadways                           0.273383
# hillshade_9am                                         0.088692
# hillshade_noon                                        0.025591
# hillshade_3pm                                        -0.042049
# horizontal_dist_to_fire_points                        1.000000
# wilderness_area_1                                     0.328827
# wilderness_area_2                                     0.057957
# wilderness_area_3                                    -0.353730
# wilderness_area_4                                    -0.052481
# cover_type                                            0.021979
#
#                                 wilderness_area_1  wilderness_area_2  \
# elevation                               -0.074194           0.293780
# aspect                                  -0.119261           0.079559
# slope                                   -0.211997          -0.014114
# horizontal_dist_to_hydrology            -0.142245           0.058207
# vertical_dist_to_hydrology              -0.165061          -0.019340
# horizontal_dist_to_roadways              0.446747          -0.245640
# hillshade_9am                            0.181174           0.005351
# hillshade_noon                          -0.019655           0.043954
# hillshade_3pm                           -0.120490           0.020313
# horizontal_dist_to_fire_points           0.328827           0.057957
# wilderness_area_1                        1.000000          -0.256434
# wilderness_area_2                       -0.256434           1.000000
# wilderness_area_3                       -0.874260          -0.232865
# wilderness_area_4                       -0.053796          -0.014329
# cover_type                              -0.002608          -0.099298
#
#                                 wilderness_area_3  wilderness_area_4  \
# elevation                               -0.051586          -0.167524
# aspect                                   0.077403           0.031304
# slope                                    0.216616           0.033690
# horizontal_dist_to_hydrology             0.120530          -0.054809
# vertical_dist_to_hydrology               0.176895          -0.011255
# horizontal_dist_to_roadways             -0.321413          -0.065821
# hillshade_9am                           -0.179672          -0.048279
# hillshade_noon                          -0.001595          -0.002464
# hillshade_3pm                            0.107467           0.034523
# horizontal_dist_to_fire_points          -0.353730          -0.052481
# wilderness_area_1                       -0.874260          -0.053796
# wilderness_area_2                       -0.232865          -0.014329
# wilderness_area_3                        1.000000          -0.048852
# wilderness_area_4                       -0.048852           1.000000
# cover_type                               0.046222           0.048261
#
#                                 cover_type
# elevation                        -0.472416
# aspect                           -0.023925
# slope                             0.085259
# horizontal_dist_to_hydrology      0.117451
# vertical_dist_to_hydrology        0.116418
# horizontal_dist_to_roadways      -0.050993
# hillshade_9am                     0.038866
# hillshade_noon                    0.020962
# hillshade_3pm                    -0.037835
# horizontal_dist_to_fire_points    0.021979
# wilderness_area_1                -0.002608
# wilderness_area_2                -0.099298
# wilderness_area_3                 0.046222
# wilderness_area_4                 0.048261
# cover_type                        1.000000

# %%
CT_dataset.change_points
# Out:
# [123785, 247570, 371355]

# %%
with pd.ExcelWriter(f'outputs/covertype/CD_delta_vs_ro_chp_tabs.xlsx') as writer:

    for chp in CT_dataset.change_points:
        drift_threshold = 0.1
        summary_df = pd.DataFrame(columns=['feat_1', 'feat_2', 'ref_corr', 'analysis_corr', 'corr_delta', 'feat_1_cd_score', 'feat_2_cd_score', 'delta_cd_score'])

        corr_df_delta = dde_exp_eq_radius.corr_scores[chp]['corr_delta']
        corr_df_analysis = dde_exp_eq_radius.corr_scores[chp]['analysis']
        corr_df_ref = dde_exp_eq_radius.corr_scores[chp]['reference']

        cd_score_df = dde_exp_eq_radius.results_all.loc[dde_exp_eq_radius.results_all['change_point']==chp].iloc[0]

        for pair in itertools.combinations(dde_exp_eq_radius.dataset.full_df.columns, 2):
            feat1 = list(pair)[0]
            feat2 = list(pair)[1]

            summary_df.loc[len(summary_df.index)] = [feat1, feat2, np.abs(corr_df_ref.loc[feat1, feat2]), np.abs(corr_df_analysis.loc[feat1, feat2]), corr_df_delta.loc[feat1, feat2], cd_score_df[feat1], cd_score_df[feat2], np.abs(cd_score_df[feat1]-cd_score_df[feat2])]

        summary_df['feat_1_drift'] = np.where(summary_df['feat_1_cd_score']>drift_threshold, 1, 0)
        summary_df['feat_2_drift'] = np.where(summary_df['feat_2_cd_score']>drift_threshold, 1, 0)
        summary_df['feat_pair_drift'] = np.where(summary_df['feat_1_drift'] & summary_df['feat_2_drift'], 1, 0)

        summary_df.to_excel(writer, sheet_name=f'{chp}', index=False)

# %%
summary_df = summary_df.sort_values(by=['corr_delta'], ascending=False)

# %%
summary_df
# Out:
#                            feat_1                       feat_2  ref_corr  \
# 96              wilderness_area_1            wilderness_area_3  0.863321
# 100             wilderness_area_2            wilderness_area_4  0.019128
# 45   horizontal_dist_to_hydrology            wilderness_area_1  0.457532
# 48   horizontal_dist_to_hydrology            wilderness_area_4  0.059007
# 9                       elevation            wilderness_area_1  0.372684
# ..                            ...                          ...       ...
# 14                         aspect                        slope  0.608574
# 99              wilderness_area_2            wilderness_area_3  0.232372
# 17                         aspect  horizontal_dist_to_roadways  0.080694
# 68    horizontal_dist_to_roadways                   cover_type  0.490212
# 97              wilderness_area_1            wilderness_area_4  0.071065
#
#      analysis_corr  corr_delta  feat_1_cd_score  feat_2_cd_score  \
# 96        0.019278    0.844043         0.541940         0.365998
# 100       0.861518    0.842390         0.365868         0.542663
# 45        0.093702    0.551234         0.080801         0.541940
# 48        0.402748    0.461755         0.080801         0.542663
# 9         0.065456    0.438140         0.102926         0.541940
# ..             ...         ...              ...              ...
# 14        0.606681    0.001893         0.090526         0.071732
# 99        0.233245    0.000872         0.365868         0.365998
# 17        0.081110    0.000416         0.090526         0.079738
# 68        0.489935    0.000278         0.079738         0.006838
# 97        0.071207    0.000142         0.541940         0.542663
#
#      delta_cd_score  feat_1_drift  feat_2_drift  feat_pair_drift
# 96         0.175941             1             1                1
# 100        0.176795             1             1                1
# 45         0.461139             0             1                0
# 48         0.461862             0             1                0
# 9          0.439013             1             1                1
# ..              ...           ...           ...              ...
# 14         0.018794             0             0                0
# 99         0.000131             1             1                1
# 17         0.010788             0             0                0
# 68         0.072900             0             0                0
# 97         0.000723             1             1                1
#
# [105 rows x 11 columns]

# %%
def get_roc_auc(scores, ys):
    # false positive rate
    FPR = []
    # true positive rate
    TPR = []
    # Iterate thresholds from 0.0 to 1.0
    thresholds = np.arange(0.0, 1.01, 0.2)
    # array([0. , 0.2, 0.4, 0.6, 0.8, 1. ])

    # get number of positive and negative examples in the dataset
    P = sum(y)
    N = len(y) - P

    # iterate through all thresholds and determine fraction of true positives
    # and false positives found at this threshold
    for thresh in thresholds:
        FP=0
        TP=0
        thresh = round(thresh,2) #Limiting floats to two decimal points, or threshold 0.6 will be 0.6000000000000001 which gives FP=0
        for i in range(len(score)):
            if (score[i] >= thresh):
                if y[i] == 1:
                    TP = TP + 1
                if y[i] == 0:
                    FP = FP + 1
        FPR.append(FP/N)
        TPR.append(TP/P)

    auc = -1 * np.trapz(TPR, FPR)

    plt.plot(FPR, TPR, linestyle='--', marker='o', color='darkorange', lw = 2, label='ROC curve', clip_on=False)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve, AUC = %.2f'%auc)
    plt.legend(loc="lower right")
    plt.savefig('AUC_example.png')
    plt.show()

# %%
def plot_lift_curve(y_pred, y_val, step=0.01):

    #Define an auxiliar dataframe to plot the curve
    aux_lift = pd.DataFrame()
    #Create a real and predicted column for our new DataFrame and assign values
    aux_lift['real'] = y_val
    aux_lift['predicted'] = y_pred
    #Order the values for the predicted probability column:
    aux_lift.sort_values('predicted',ascending=False,inplace=True)

    #Create the values that will go into the X axis of our plot
    x_val = np.arange(step,1+step,step)
    #Calculate the ratio of ones in our data
    ratio_ones = aux_lift['real'].sum() / len(aux_lift)
    #Create an empty vector with the values that will go on the Y axis our our plot
    y_v = []

    #Calculate for each x value its correspondent y value
    for x in x_val:
        num_data = int(np.ceil(x*len(aux_lift))) #The ceil function returns the closest integer bigger than our number
        data_here = aux_lift.iloc[:num_data,:]   # ie. np.ceil(1.4) = 2
        ratio_ones_here = data_here['real'].sum()/len(data_here)
        y_v.append(ratio_ones_here / ratio_ones)

   #Plot the figure
    fig, axis = plt.subplots()
    fig.figsize = (40,40)
    axis.plot(x_val, y_v, 'g-', linewidth = 3, markersize = 5)
    axis.plot(x_val, np.ones(len(x_val)), 'k-')
    axis.set_xlabel('Proportion of sample')
    axis.set_ylabel('Lift')
    plt.title('Lift Curve')
    plt.show()

# %%
score = summary_df.ref_corr #np.array([0.8, 0.6, 0.4, 0.2])
y = summary_df.feat_pair_drift #np.array([1,0,1,0])

# %%
get_roc_auc(score, y)

# %%
plot_lift_curve(score, y)
